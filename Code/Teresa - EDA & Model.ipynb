# %%
pip install ucimlrepo

# %%
from ucimlrepo import fetch_ucirepo

# fetch dataset
dermatology = fetch_ucirepo(id=33)

# data (as pandas dataframes)
X = dermatology.data.features
y = dermatology.data.targets

# metadata
print(dermatology.metadata)

# variable information
print(dermatology.variables)
# Out:
# {'uci_id': 33, 'name': 'Dermatology', 'repository_url': 'https://archive.ics.uci.edu/dataset/33/dermatology', 'data_url': 'https://archive.ics.uci.edu/static/public/33/data.csv', 'abstract': 'Aim for this dataset is to determine the type of Eryhemato-Squamous Disease.', 'area': 'Health and Medicine', 'tasks': ['Classification'], 'characteristics': ['Multivariate'], 'num_instances': 366, 'num_features': 34, 'feature_types': ['Categorical', 'Integer'], 'demographics': ['Age'], 'target_col': ['class'], 'index_col': None, 'has_missing_values': 'yes', 'missing_values_symbol': 'NaN', 'year_of_dataset_creation': 1998, 'last_updated': 'Wed Feb 14 2024', 'dataset_doi': '10.24432/C5FK5P', 'creators': ['Nilsel Ilter', 'H. Guvenir'], 'intro_paper': {'ID': 387, 'type': 'NATIVE', 'title': 'Learning differential diagnosis of erythemato-squamous diseases using voting feature intervals', 'authors': 'H. Altay Güvenir, G. Demiröz, N. Ilter', 'venue': 'Artif. Intell. Medicine', 'year': 1998, 'journal': 
# ...

# %%
import pandas as pd

# Create pandas dataframe
df = pd.concat([X, y], axis=1)

# %%
# First 5 rows
df.head()
# Out:
#    erythema  scaling  definite-borders  itching  koebner phenomenon  \
# 0         2        2                 0        3                   0
# 1         3        3                 3        2                   1
# 2         2        1                 2        3                   1
# 3         2        2                 2        0                   0
# 4         2        3                 2        2                   2
#
#    polygonal papules  follicular papules  oral-mucosal involvement  \
# 0                  0                   0                         0
# 1                  0                   0                         0
# 2                  3                   0                         3
# 3                  0                   0                         0
# 4                  2                   0                         2
#
#    knee elbow involvement  scalp involvement  ...  \
# 0                       1                  0  ...
# ...

# %%
# Summary statistics
df.describe()
# Out:
#          erythema     scaling  definite-borders     itching  \
# count  366.000000  366.000000        366.000000  366.000000
# mean     2.068306    1.795082          1.549180    1.366120
# std      0.664753    0.701527          0.907525    1.138299
# min      0.000000    0.000000          0.000000    0.000000
# 25%      2.000000    1.000000          1.000000    0.000000
# 50%      2.000000    2.000000          2.000000    1.000000
# 75%      2.000000    2.000000          2.000000    2.000000
# max      3.000000    3.000000          3.000000    3.000000
#
#        koebner phenomenon  polygonal papules  follicular papules  \
# count          366.000000         366.000000          366.000000
# mean             0.633880           0.448087            0.166667
# std              0.908016           0.957327            0.570588
# min              0.000000           0.000000            0.000000
# 25%              0.000000           0.000000            0.000000
# ...

# %%
# Find duplicate values total
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Find missing values total
df.isnull().sum()
# Out:
# erythema                                       0
# scaling                                        0
# definite-borders                               0
# itching                                        0
# koebner phenomenon                             0
# polygonal papules                              0
# follicular papules                             0
# oral-mucosal involvement                       0
# knee elbow involvement                         0
# scalp involvement                              0
# family history                                 0
# melanin incontinence                           0
# eosinophils in the infiltrate                  0
# pnl infiltrate                                 0
# fibrosis of the papillary dermis               0
# exocytosis                                     0
# acanthosis                                     0
# hyperkeratosis                                 0
# parakeratosis                                  0
# ...

# %%
import matplotlib.pyplot as plt

# Set height, width, # of bins and edge color of histogram
df.hist(figsize=(12, 8), bins=20, edgecolor='black')
# Set title of histogram
plt.suptitle('Data Distributions', fontsize=16)
# Plot data
plt.show()

# %%
import seaborn as sns
import pandas as pd

# Create boxplots
plt.figure(figsize=(125, 30))
sns.boxplot(data=df, width=0.3)
plt.show()

# %%
# Impute missing values with median age
median_age = df['age'].median()
X.loc[:, 'age'] = X['age'].fillna(median_age)

# %%
from sklearn.model_selection import train_test_split

# Split data into train test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,     # 20% for testing, 80% for training
    random_state=42    # Set seed for reproducibility
)

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)
X_train_balanced, y_train_balanced = smote.fit_resample(X_train, y_train)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline

# Create a pipeline that standardizes the data then applies SVM
svm_pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('svm', SVC(kernel='rbf'))
])

# %%
from sklearn.model_selection import GridSearchCV

# Define parameter grid
param_grid = {
    'svm__C': [0.1, 1, 10, 100],
    'svm__gamma': [0.001, 0.01, 0.1, 1],
    'svm__kernel': ['rbf', 'linear']
}

grid_search = GridSearchCV(
    svm_pipeline,
    param_grid=param_grid,
    cv=5,
    scoring='accuracy',
    verbose=1,
    n_jobs=-1
)

# Fit the grid search
grid_search.fit(X_train_balanced, y_train_balanced)

# Print the best results
print("Best parameters:", grid_search.best_params_)
print("Best cross-validation score:", grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# Best parameters: {'svm__C': 10, 'svm__gamma': 0.001, 'svm__kernel': 'linear'}
# Best cross-validation score: 0.9876499053229539
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# Use the best model
best_model = grid_search.best_estimator_
predictions = best_model.predict(X_test)

# %%
# 1. For permutation importance, use accuracy instead of probabilities
from sklearn.inspection import permutation_importance

result = permutation_importance(
    best_model, X_test, y_test,
    n_repeats=10,
    random_state=42
)

# Get and display importance values
importance = result.importances_mean
feature_names = X_train_balanced.columns if hasattr(X_train_balanced, 'columns') else [f'Feature {i}' for i in range(X_train_balanced.shape[1])]
for i, name in enumerate(feature_names):
    print(f"{name}: {importance[i]:.4f}")
# Out:
# erythema: 0.0000
# scaling: 0.0014
# definite-borders: 0.0000
# itching: 0.0257
# koebner phenomenon: 0.0203
# polygonal papules: 0.0000
# follicular papules: 0.0027
# oral-mucosal involvement: 0.0000
# knee elbow involvement: 0.0000
# scalp involvement: 0.0000
# family history: 0.0000
# melanin incontinence: 0.0000
# eosinophils in the infiltrate: 0.0000
# pnl infiltrate: 0.0297
# fibrosis of the papillary dermis: 0.0419
# exocytosis: 0.0149
# acanthosis: 0.0000
# hyperkeratosis: 0.0000
# parakeratosis: 0.0027
# clubbing of the rete ridges: 0.0108
# elongation of the rete ridges: 0.0041
# thinning of the suprapapillary epidermis: 0.0189
# spongiform pustule: 0.0000
# munro microabcess: 0.0000
# focal hypergranulosis: 0.0000
# disappearance of the granular layer: 0.0041
# vacuolisation and damage of the basal layer: 0.0000
# spongiosis: 0.0162
# saw-tooth appearance of retes: 0.0000
# follicular horn plug: 0.0014
# perifollicular parakeratosis: 0.0014
# ...
